# %%
#task-4
class Account:
    count = 0
    def __init__(self,name,age,occupation,amount):
        self.name = name
        self.age = age
        self.occupation = occupation
        self.amount = amount
        Account.count += 1
    def addMoney(self,amount_2):
        self.amount_2 = amount_2
        self.x = self.amount + self.amount_2
    def withdrawMoney(self,amount_2):
        self.amount_2 = amount_2
        self.x = self.amount - self.amount_2
    def printDetails(self):
        print(f"Name:{self.name}")
        print(f"Age:{self.age}")
        print(f"Occupation: {self.occupation}")
        print(f"Total Amount: {self.x}")
        #print(f"total Amount: {self.y}")

print('No of account holders:', Account.count)
print("=========================")
p1 = Account("Abdul", 45, "Service Holder", 500000)
p1.addMoney(300000)
p1.printDetails()
print("=========================")
p2 = Account("Rahim", 55, "Businessman", 700000)
p2.withdrawMoney(700000)
p2.printDetails()
print("=========================")
p3 = Account("Ashraf", 62, "Govt. Officer", 200000)
p3.withdrawMoney(250000)
p3.printDetails()
print("=========================")
print('No of account holders:', Account.count)
# Out:
# No of account holders: 0
# ...
# Name:Abdul
# Age:45
# Occupation: Service Holder
# Total Amount: 800000
# ...
# Name:Rahim
# Age:55
# Occupation: Businessman
# Total Amount: 0
# ...
# Name:Ashraf
# Age:62
# Occupation: Govt. Officer
# Total Amount: -50000
# ...
# No of account holders: 3

# %%
#task-5
class Smartphone:
    def __init__(self,name = None ):
        self.name = name
        self.x = []
    def addFeature(self,f1,f2):
        if self.name == None:
            print("Feature can not be added without phone name")
        self.f1 = f1
        self.f2 = f2
        self.x.append([self.f1,self.f2])
    def setName(self,name):
        self.name = name
    def printDetail(self):
        print(f"Phone Name:{self.name}")
        for i in range(len(self.x)):
            print(self.x[i][0],":",self.x[i][1])
            #print(self.x[i][1])
        #print(f"{self.f1}:{self.f2}")
s1 = Smartphone()
print("=================================")
s1.addFeature("Display", "6.1 inch")
print("=================================")
s1.setName("Samsung Note 20")
s1.addFeature("Display", "6.1 inch")
s1.printDetail()
print("=================================")
s2 = Smartphone("Iphone 12 Pro")
s2.addFeature("Display", "6.2 inch")
s2.addFeature("Ram", "6 GB")
print("=================================")
s2.printDetail()
s2.addFeature("Display", "Amoled panel")
s2.addFeature("Ram", "DDR5")
print("=================================")
s2.printDetail()
print("=================================")
# Out:
# ...
# Feature can not be added without phone name
# ...
# Phone Name:Samsung Note 20
# Display : 6.1 inch
# Display : 6.1 inch
# ...
# Phone Name:Iphone 12 Pro
# Display : 6.2 inch
# Ram : 6 GB
# ...
# Phone Name:Iphone 12 Pro
# Display : 6.2 inch
# Ram : 6 GB
# Display : Amoled panel
# Ram : DDR5
# ...

# %%
#task-6
class Student:
    count = 0
    dic = {"CSE":[],"BBA":[]}
    def __init__(self,name,dept):
        self.name = name
        self.dept = dept
        self.x = len(Student.dic[dept]) + 1
        #self.y = 0
        Student.count += 1



        print(f"Creating Student Number :{Student.count} ")
    def individualInfo(self):
        print(f"{self.name} is from {self.dept} department.")
        print(f"Serial of {self.name} among all students' is :{Student.count}")
        print(f"Serial of {self.name} in {self.dept} department is :{self.x}")
    def totalInfo(self):
        print(f"Total Number of Student:{Student.count}")
        print(f"Total number of {self.dept} Student: ")
        print(f"Total number of {self.dept} Student: ")

s1 = Student("Naruto", "CSE")
print('----------------------')
s1.individualInfo()
print('#############################')
s1.totalInfo()
print('============================')
s2 = Student("Sakura", "BBA")
print('----------------------')
s2.individualInfo()
print('#############################')
s2.totalInfo()
print('============================')
s3 = Student("Shikamaru", "CSE")
print('----------------------')
s3.individualInfo()
print('#############################')
s3.totalInfo()
print('============================')
s4 = Student("Deidara", "BBA")
print('----------------------')
s4.individualInfo()
print('#############################')
s4.totalInfo()
# Out:
# Creating Student Number :1
# ----------------------
# Naruto is from CSE department.
# Serial of Naruto among all students' is :1
# Serial of Naruto in CSE department is :1
# #############################
# Total Number of Student:1
# Total number of CSE Student:
# Total number of CSE Student:
# ...
# Creating Student Number :2
# ----------------------
# Sakura is from BBA department.
# Serial of Sakura among all students' is :2
# Serial of Sakura in BBA department is :1
# #############################
# Total Number of Student:2
# Total number of BBA Student:
# Total number of BBA Student:
# ...
# Creating Student Number :3
# ----------------------
# Shikamaru is from CSE department.
# Serial of Shikamaru among all students' is :3
# Serial of Shikamaru in CSE department is :1
# #############################
# Total Number of Student:3
# Total number of CSE Student:
# Total number of CSE Student:
# ...
# Creating Student Number :4
# ----------------------
# Deidara is from BBA department.
# ...

# %%
#task-7
class book:
    def __init__(self, name):
        self.name = name
        self.genre='biography'
    def review(self):
        print('This book is just out of the world,mind-blowing!')
class fiction(book):
    def __init__(self,name,genre):
        #self.part1 = part1


        #print(f"{self.part1} which is a {self.part2}\n",end="")
        super().__init__(name)
        self.genre = genre
        #print(f"The Shining which is a Psychological horror\n"
        #print(f"{self.part1 which is a {self.part2} {super().review()}")
    def review(self):
        #print("is just out of the world, mind-blowing!")
        print(f"{self.name} which is a {self.genre}\n",end="")
        print("is just out of the world, mind-blowing!")

class nonfiction(book):
    def __init__(self,name):
        #self.name = name
        book.__init__(self,name)

        #print(f"{self.part1} which is a {super().review()}")
    def review(self):
        print(f"{self.name} which is a {self.genre}")
        print("is just out of the world, mind-blowing!")
b1 = fiction('The Shining','Psychological horror')
b2 = nonfiction('A Beautiful Mind')
b1.review()
print('=========================')
b2.review()
print('=========================')
# Out:
# The Shining which is a biography
# is just out of the world, mind-blowing!
# ...
# A Beautiful Mind which is a biography
# is just out of the world, mind-blowing!
# ...

# %%
#task-8
class Processor:
    def __init__(self, model, thread, core):
        self.model = model
        self.core = core
        self.thread = thread
    def getInfo(self):
        return "Model:"+str(self.model)+ "\nCores:"+str(self.core)+ "\nThreads:"+ str(self.thread)
class Intel(Processor):
    def __init__(self,model,core,thread,price):
        self.core = core
        self.thread = thread
        self.model = model
        self.price = price
        #print(f"{super().getInfo()}\nPrice: {self.price} taka")
    def getInfo(self):
        #print(f"Model:"+str(self.model)+ "\nCores:"+str(self.core)+ "\nThreads:"+ str(self.thread) +"\nPrice:" +self.price)
        print(f"{super().getInfo()}\nPrice: {self.price} taka")
class AMD(Processor):
    def __init__(self,model,core,thread,price):
        self.core = core
        self.thread = thread
        self.model = model
        self.price = price
        #print(f"{super().getInfo()}\nPrice: {self.price} taka")
    def getInfo(self):
        #print(f"Model:"+str(self.model)+ "\nCores:"+str(self.core)+ "\nThreads:"+ str(self.thread))
        print(f"{super().getInfo()}\nPrice: {self.price} taka")


p1 = Intel("Intel i5 10th Gen",6,12,17000)
p2 = AMD("Ryzen 5 3500X",6,6,13800)
p3 = AMD("Ryzen 5 3600",6,12,16900)
print('======================')
p1.getInfo()
print('======================')
p2.getInfo()
print('======================')
p3.getInfo()
# Out:
# ...
# Model:Intel i5 10th Gen
# Cores:6
# Threads:12
# Price: 17000 taka
# ...
# Model:Ryzen 5 3500X
# Cores:6
# Threads:6
# Price: 13800 taka
# ...
# Model:Ryzen 5 3600
# Cores:6
# Threads:12
# Price: 16900 taka

# %%
#task-9
class Fruit:
    Total_order=0
    def __init__(self, Order_ID, weight):
        self.Order_ID=Order_ID
        self.weight = weight
        Fruit.Total_order = Fruit.Total_order+1
    def __str__(self):
        return str(self.Order_ID) + ", Weight:" + str(self.weight)
class Mango(Fruit):
    emp = []

    def __init__(self,Order_ID,weight,variety,price):
        super().__init__(Order_ID,weight)
        self.variety = variety
        self.price = price
        self.x = self.weight * self.price
        self.emp.append(self.x)
        #print(self.x)
    def __str__(self):
        return self.Order_ID + ", Weight : "+ str(self.weight) + " Variety : " + str(self.variety) + ",\n" + "Total price : " + str(self.x)
    def __add__(self,other):
        self.y1 = self.variety + other.variety
        self.y2 = self.price + other.price
        self.x1 = str(self.y1) + str(self.y2)
        #return Fruit(self.x1)
        #print(self.x1)
        self.y = str(self.emp[0] + self.emp[1])
        #print(self.y)
        return f"The total Price of the orders are : {self.y}"


class JackFruit(Fruit):
    emp1 = []
    def __init__(self,Order_ID,weight,price):
        super().__init__(Order_ID,weight)
        self.price = price
        self.y = self.weight * self.price
        self.emp1.append(self.y)
    def __str__(self):
        return self.Order_ID + " , Weight : " + str(self.weight) + " , Total price : " + str(self.y)
    def __add__(self,other):
        self.z1 = self.price + other.price
        self.z2 = self.weight + other.weight
        self.x2 = str(self.z1) + str(self.z2)
        self.k = str(self.emp1[0] + self.emp1[1])
        return f"The total Price of the orders are: {self.k}"

m1=Mango("Order Id 1", 5,"GopalVog",250)
print(m1)
m2=Mango("Order Id 2", 5,"HariVanga", 230)
print(m2)
j1=JackFruit("Order Id 3", 5,250)
print(j1)
j2=JackFruit("Order Id 4", 4,210)
print(j2)
print("Total number of Orders:"+str(Fruit.Total_order))
print("==================")
print(m1+m2)
print("==================")
print(j1+j2)
# Out:
# Order Id 1, Weight : 5 Variety : GopalVog,
# Total price : 1250
# Order Id 2, Weight : 5 Variety : HariVanga,
# Total price : 1150
# Order Id 3 , Weight : 5 , Total price : 1250
# Order Id 4 , Weight : 4 , Total price : 840
# Total number of Orders:4
# ...
# The total Price of the orders are : 2400
# ...
# The total Price of the orders are: 2090

# %%
#task-10
class Student:
    def __init__(self,name,ID):
        self.name = name
        self.ID = ID
    def Details(self):
        return "Name: "+self.name+"\n"+"ID: "+self.ID+"\n"
class CSEStudent(Student):
    def __init__(self,name,ID,semester):
        super().__init__(name,ID)
        self.semester = semester
        print(f"{super().Details()}Current semester : {self.semester}")
    def addCourseWithMarks(self,c1,m,c2,m,c3,m,c4 = "CSE461",m = 87.0):
        self.c1 = c1
        self.m = m
        self.c2 = c2
        self.m = m
        self.c3 = c3
        self.m = m
        self.c4 = c4
        self.m = m
    def showGPA(self):

        GPA =
        if self.m >= 85:
            print("4.0")
        elif 80 <= self.m <= 84:
            print("3.3")
        elif 70 <= self.m <= 79:
            print("3.0")
        elif 65 <= self.m <= 69:
            print("2.3")
        elif 57 <= self.m <= 64:
            print("2.0")
        elif 55 <= self.m <= 56:
            print("1.3")
        elif 50 <= self.m <= 54:
            print("1.0")
        elif self.m > 50:
            print("0.0")

Bob = CSEStudent("Bob","20301018","Fall 2020")
Carol = CSEStudent("Carol","16301814","Fall 2020")
Anny = CSEStudent("Anny","18201234","Fall 2020")
print("#########################")
print(Bob.Details())
print("#########################")
print(Carol.Details())
print("#########################")
print(Anny.Details())
print("#########################")
Bob.addCourseWithMarks("CSE111",83.5,"CSE230",73.0,"CSE260",92.5)
Carol.addCourseWithMarks("CSE470",62.5,"CSE422",69.0,"CSE460",76.5,"CSE461",87.0)
Anny.addCourseWithMarks("CSE340",45.5,"CSE321",95.0,"CSE370",91.0)
print("----------------------------")
Bob.showGPA()
print("----------------------------")
Carol.showGPA()
print("----------------------------")
Anny.showGPA()
# Out:
#   File "<ipython-input-58-7378811aa6f2>", line 24
#     GPA =
#           ^
# SyntaxError: invalid syntax

# %%
#task-11
class Transport:
    total_traveller = 0
    def __init__(self, name, fare):
        self.name = name
        self.baseFare = fare
        Transport.total_traveller += 1
    def __str__(self):
        s = "Name: "+self.name+", Base fare: "+str(self.baseFare)
        return s
class Bus(Transport):
    def __init__(self,name,fare):
        super().__init__(name,fare)
        print(f"Base-fare of {self.name} is {self.baseFare} Taka")
        print("======================================")
    def addPassengerWithBags(self,name1,num1,name2,num2,name3="Carol",num3 = 3):
        self.name1 = name1
        self.num1 = num1
        self.name2 = name2
        self.num2 = num2
        self.name3 = name3
        self.num3 = num3
        #self.count = 0
        print(f"{super().__str__()}")
        print(f"Total Passenger(s):{Transport.total_traveller}")
        #self.count += 1
        print(f"Passenger details:")
        if self.num1 >= 6:
            print(f"Name:{self.name1},Fare:{self.baseFare + 105}")
        elif 3 <=self.num1 >=5:
            print(f"Name:{self.name1},Fare:{self.baseFare + 60}")
        elif self.num1 <= 2:
             print(f"Name:{self.name1},Fare:{self.baseFare}")
        if self.num2 >= 6:
            print(f"Name:{self.name2},Fare:{self.baseFare + 105}")
        elif 3 <=self.num2 >=5:
            print(f"Name:{self.name2},Fare:{self.baseFare + 60}")
        elif self.num2 <= 2:
             print(f"Name:{self.name2},Fare:{self.baseFare}")
        print(f"Name:{self.name3},Fare:{self.baseFare+60}")
class Train(Transport):
    def __init__(self,name,fare):
        super().__init__(name,fare)
        print(f"Base-fare of {self.name} is {self.baseFare} Taka")
        print("====================================")
    def addPassengerWithBags(self,name1,num1,name2,num2):
        self.name1 = name1
        self.num1 = num1
        self.name2 = name2
        self.num2 = num2
        # print(f"{super().__str__()}\nTotal Passenger(s):{Transport.total_traveller}")
        # print(f"Passenger details:")
        print(f"{super().__str__()}\nTotal Passenger(s):{Transport.total_traveller}\nPassenger details:\nName:{self.name1},Fare:{self.baseFare}\nName:{self.name2},Fare:{self.baseFare + 60}")
        # if self.num1 >= 6:
        #     print(f"Name:{self.name1},Fare:{self.baseFare + 105}")
        # elif 3 <=self.num1 >=5:
        #     print(f"Name:{self.name1},Fare:{self.baseFare + 60}")
        # if self.num1 <= 2:
        #      print(f"Name:{self.name1},Fare:{self.baseFare}")
        # if self.num2 >= 6:
        #     print(f"Name:{self.name2},Fare:{self.baseFare + 105}")
        if 3 <=self.num2 >=5:        #
            print(f"Name:{self.name2},Fare:{self.baseFare + 60}")
        # elif self.num2 <= 2:
        #      print(f"Name:{self.name2},Fare:{self.baseFare}")
        #print(f"Name:{self.name3},Fare:{self.baseFare+60}")
t1 = Bus("Volvo", 950)
print("=================================")
t1.addPassengerWithBags("David", 6, "Mike", 1, "Carol", 3)
print("=================================")
print(t1)
print("=================================")
t2 = Train("Silk City", 850)
print("=================================")
t2.addPassengerWithBags("Bob", 2, "Simon", 4)
print("=================================")
print(t2)
print("=================================")
print("Total Passengers in Transport: ", Transport.total_traveller )
# Out:
# Base-fare of Volvo is 950 Taka
# ...
# Name: Volvo, Base fare: 950
# Total Passenger(s):1
# Passenger details:
# Name:David,Fare:1055
# Name:Mike,Fare:950
# Name:Carol,Fare:1010
# ...
# Name: Volvo, Base fare: 950
# ...
# Base-fare of Silk City is 850 Taka
# ...
# Name: Silk City, Base fare: 850
# Total Passenger(s):2
# Passenger details:
# Name:Bob,Fare:850
# Name:Simon,Fare:910
# ...
# Name: Silk City, Base fare: 850
# ...
# Total Passengers in Transport:  2

# %%
class Transport:
    total_traveller = 0
    def __init__(self, name, fare):
        self.name = name
        self.baseFare = fare
        Transport.total_traveller += 1
    def __str__(self):
        s = "Name: "+self.name+", Base fare: "+str(self.baseFare)
        return s
        #Transport.total_traveller += 1
class Bus(Transport):
    def __init__(self,name,fare):
        super().__init__(name,fare)
        print(f"Base-fare of {self.name} is {self.baseFare} Taka")
        print("========================================")
    def addPassengerWithBags(self,name1,num1,name2,num2,name3="Carol",num3=3):
        self.name1 = name1
        self.num1 = num1
        self.name2 = name2
        self.num2 = num2
        self.name3 = name3
        self.num3 = num3
        print(f"{super().__str__()}")
        print(f"Total Passenger(s):{Transport.total_traveller}")
        print(f"Passenger details:")
        if self.num1 >= 6:
            #self.baseFare += 105
            print(f"\nName:{self.name1},Fare:{self.baseFare + 105}")
        elif 3 <=self.num1 >=5:
            print(f"\nName:{self.name1},Fare:{self.baseFare + 60}")
        elif self.num1 <= 2:
             print(f"\nName:{self.name1},Fare:{self.baseFare}")
        if self.num2 >= 6:
            #self.baseFare += 105
            print(f"\nName:{self.name2},Fare:{self.baseFare + 105}")
        elif 3 <=self.num2 >=5:
            print(f"\nName:{self.name2},Fare:{self.baseFare + 60}")
        elif self.num2 <= 2:
             print(f"\nName:{self.name2},Fare:{self.baseFare}")

    print(f"\nName:{self.name3},Fare:{self.baseFare+60}")


class Train(Transport):
    def __init__(self,name,fare):
        super().__init__(name,fare)
        print(f"Base-fare of {self.name} is {self.baseFare} Taka")
    def addPassengerWithBags(self,name1,num1,name2,num2):
        self.name1 = name1
        self.num1 = num1
        self.name2 = name2
        self.num2 = num2
        print(f"{super().__str__()}\nTotal Passenger(s):{Transport.total_traveller}\nPassenger details:\nName:{self.name1},Fare:{self.baseFare}\nName:{self.name2},Fare:{self.baseFare}")

t1 = Bus("Volvo", 950)
print("=================================")
t1.addPassengerWithBags("David", 6, "Mike", 1, "Carol", 3)
print("=================================")
print(t1)
print("=================================")
t2 = Train("Silk City", 850)
print("=================================")
t2.addPassengerWithBags("Bob", 2, "Simon", 4)
print("=================================")
print(t2)
print("=================================")
print("Total Passengers in Transport: ", Transport.total_traveller )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8133e5d64843> in <module>
#      39              print(f"\nName:{self.name2},Fare:{self.baseFare}")
#      40
# ---> 41 print(f"\nName:{self.name3},Fare:{self.baseFare+60}")
#      42
#      43
#
# NameError: name 'self' is not defined

# %%
#task-13
class University:
    name = "ABC University"
    numberOfStudents = 0
    admissionFee = 28000
    Library = 2000
    def __init__(self, n,i):
        self.stName = n
        self.stId = i
    def payment(self):
        return self.admissionFee + self.Library
    def __str__(self):
        return "Student Name: {}, ID: {}\nFee:{}".format(self.stName, self.stId, self.payment())
class CSE_dept:
    def __init__(self,name,id,fee = 80050):
        self.name = name
        self.id = id
        self.fee = fee
    def payment_details(self):
        print(f"Student Name:{self.name},ID:{self.id}\nFee:{self.fee}")


c1 = CSE_dept("Mary","5678")
print(c1)
c1.payment_details()
print("===========================")
p1 = PHR_dept("Simon","91011")
print(p1)
p1.payment_details()
print("===========================")
c2 = CSE_dept("Adam","1234", 12)
print(c2)
c2.payment_details()
print("===========================")
p2 = PHR_dept("David","121314", 15)
print(p2)
p2.payment_details()
print("===========================")
print("Total Number of Students:",
University.numberOfStudents)
print("Total University Revenue:", (c1 + c2) + (p1 + p2))
print("===========================")
print("Due to the pandemic, admission and library fees have been reduced for all departments. ")
University.admissionFee -= 1000
University.Library -= 100
print("The credit, semester and lab fees have been reduced for the CSE department. ")
CSE_dept.PerCreditFee -= 100
CSE_dept.SemesterFee -= 100
CSE_dept.LabFee -=100
print("The credit and semester fees have been reduced for the PHR department.\n ")
PHR_dept.PerCreditFee -= 100
PHR_dept.SemesterFee -= 1000
print(c1)
print(p1)
print(c2)
print(p2)
print("===========================")
print("Total Number of Students:",
University.numberOfStudents)
print("Total University Revenue:", (c1 + c2) + (p1 + p2))
# Out:
# ...
# Student Name:Mary,ID:5678
# Fee:80050
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-45047ee2a2b0> in <module>
#      25 c1.payment_details()
#      26 print("===========================")
# ---> 27 p1 = PHR_dept("Simon","91011")
#      28 print(p1)
#      29 p1.payment_details()
#
# NameError: name 'PHR_dept' is not defined

# %%
#task-14
class Library:
    Total_book = 1000
    borrow_data = {}
    def __init__(self,n,id):
        self.student_name = n
        self.student_id = id
    def borrowbook(self):
        print("A book is borrowed!")
    def __str__(self):
        return "Library: XYZ"
class Student(Library):
    #super().__init__()
    def borrowbook(self,name,uni_id = "Hdw652"):
        print("A book is borrowed!")
        self.name = name
        self.uni_id = uni_id
        print(f"{self.name} book with the unique id {self.uni_id} is borrowed\nby {self.student_name}({self.student_id})")
        #print(f"Number of books available for borrowing =",Total_book-1)
    def __str__(self):
        return f"Library: XYZ\nStudent Name : {self.student_name} ID:{self.student_id}\nBooks borrowed:{self.name}"
    # borrow_data = {}
    # for i in borrow_data:
    #     k,v = i.split(":")
    #     borrow_data[k.strip()] = v
    def returnAllBooks(self):
s1 = Student("Alice",18101259)
s1.borrowbook("The Alchemist", "Hdw652")
print("===============")
print(s1)
print("===============")
print(Library.borrow_data)
print("===============")
s1.borrowbook("Wuthering Heights")
print("===============")
print(s1)
print("===============")
s2= Student("David",18141777)
s2.borrowbook("The Alchemist", "Hdw652")
print("===============")
s2.borrowbook("The Vampyre")
print("===============")
print(Library.borrow_data)
print("===============")
s1.returnAllBooks()
print("===============")
print(Library.borrow_data)
# Out:
# A book is borrowed!
# The Alchemist book with the unique id Hdw652 is borrowed
# by Alice(18101259)
# ...
# Library: XYZ
# Student Name : Alice ID:18101259
# Books borrowed:The Alchemist
# ...
# {}
# ...
# A book is borrowed!
# Wuthering Heights book with the unique id Hdw652 is borrowed
# by Alice(18101259)
# ...
# Library: XYZ
# Student Name : Alice ID:18101259
# Books borrowed:Wuthering Heights
# ...
# A book is borrowed!
# The Alchemist book with the unique id Hdw652 is borrowed
# by David(18141777)
# ...
# A book is borrowed!
# The Vampyre book with the unique id Hdw652 is borrowed
# by David(18141777)
# ...
# {}
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-5930fdcbf6dc> in <module>
#      56 print(Library.borrow_data)
#      57 print("===============")
# ---> 58 s1.returnAllBooks()
#      59 print("===============")
#      60 print(Library.borrow_data)
#
# ...

# %%
#task-15
class Player:
    database = {}
    playerNo = 0
    def __init__(self,name,team,jerseyNo):
        self.name = name
        self.team = team
        self.jerseyNo = jerseyNo
        Player.playerNo += 1

    def __str__(self):
        return "Name:{}\nTeam:{}\nJersey No:{}".format(self.name,self.team,self.jerseyNo)
class FootballPlayer(Player):
    def __init__(self,name,team,jerseyNo,goals,retirement = None):
        super().__init__(name,team,jerseyNo)
        self.goals = goals
        if retirement == None:
            self.retirement = "Not yet retired"
        else:
            self.retirement = retirement
        x = name.split()
        self.x = str(Player.playerNo) + x[0][0] + x[1][0] + str(self.jerseyNo)
        Player.database[self.x] =  [self.name,self.team,self.jerseyNo,self.goals,self.retirement]
    def __str__(self):

        return(f"Player ID :{self.x}{super().__str__()}\nGoals Scored:{self.goals}\nRetirement date:{self.retirement}")


print("Number of players:",Player.playerNo)
print("Player Database:",Player.database)
print("#################################")
p1 = FootballPlayer("Lionel Messi","Barcelona",10,231)
print("------Details of the player------")
print(p1)
print("#################################")
p2 = FootballPlayer("Cristiano Ronaldo","Juventus",7,215)
print("------Details of the player------")
print(p2)
print("#################################")
p3 = FootballPlayer("Miroslav Klose","Lazio",11,71,"11 Aug,2014")
print("------Details of the player------")
print(p3)
print("#################################")
print("Number of players:",Player.playerNo)
print("Player Database:",Player.database)
# Out:
# Number of players: 0
# Player Database: {}
# #################################
# ------Details of the player------
# Player ID :1LM10Name:Lionel Messi
# Team:Barcelona
# Jersey No:10
# Goals Scored:231
# Retirement date:Not yet retired
# #################################
# ------Details of the player------
# Player ID :2CR7Name:Cristiano Ronaldo
# Team:Juventus
# Jersey No:7
# Goals Scored:215
# Retirement date:Not yet retired
# #################################
# ------Details of the player------
# Player ID :3MK11Name:Miroslav Klose
# Team:Lazio
# Jersey No:11
# Goals Scored:71
# Retirement date:11 Aug,2014
# #################################
# Number of players: 3
# Player Database: {'1LM10': ['Lionel Messi', 'Barcelona', 10, 231, 'Not yet retired'], '2CR7': ['Cristiano Ronaldo', 'Juventus', 7, 215, 'Not yet retired'], '3MK11': ['Miroslav Klose', 'Lazio', 11, 71, '11 Aug,2014']}

# %%
#task-12
class AppleProduct:
    def __init__(self, name, model,base_price):
        self.name = name
        self.model = model
        self.base_price = base_price
    def companyInfo(self):
        st = ("Company Name: Apple\nFouder: Steve Jobs, Steve Wozniak, Ronald Wayne\nCurrentCEO: Tim Cook\nAddress: Apple Inc, 2511 Laguna Blvd, Elk Grove, CA 95758, United States")
        return st
    def feature(self):
        st = (f"Name: {self.name}\nProduct Model:{self.model}\nHardware Quality: ExcellentHardwares\nGuarantee/ Warranty: Apple Care")
        return st
    def __str__(self):
        print('This is apple product.')
    def calculatePrice(self):
        print('Total Price:', self.base_price)
class MacBookPro2020:
    def __init__(self,name,model,ram,chip,tax):
        self.name = name
        self.model = model
        self.ram = ram
        self.chip = chip
        self.tax = tax
    def calculatePrice(self):
        print(f"Product Details:")
        print(f"Name:{self.name}")
        print(f"Product Model:{self.model}")
        print(f"Hardware Quality:Excellent Hardwares")
        print(f"Guarantee/ Warranty: Apple Care")
        print(f"Ram:{self.ram}GB")
        print(f"Chip:{self.chip}")
        print(f"Company Details:")
        print(f"Company Name:Apple")
        print(f"Founder:{self.name},{self.name},{self.name}")
        print(f"Current CEO:Tim Cook")
        print(f"Addres Apple Inc,c, 2511 Laguna Blvd, Elk Grove, CA 95758, United States")
class iPhone12:
    def __init__(self,name1,model1,ram1,chip1,tax1):
        self.name1 = name1
        self.model1 = model1
        self.ram1 = ram1
        self.chip1 = chip1
        self.tax1 = tax1
    def calculatePrice(self):
        print(f"Product Details:")
        print(f"Name:{self.name1}")
        print(f"Product Model:{self.model1}")
        print(f"Hardware Quality: Excellent Hardwares")
        print(f"Guarantee/ Warranty: Apple Care")
        print(f"RAM:{self.ram1}")
        print(f"Chip:{self.chip1}")
        print(f"Company Details:")
        print(f"Company Name: Apple")
m1 = MacBookPro2020('MacBook','MacBookPro2020', 8, 'M1', 10)
print(m1)
print('====================================')
m1.calculatePrice()
print('###################################')
iphone = iPhone12('iPhone', 'iPhone 12', 8,'A14', 5)
print(iphone)
print('====================================')
iphone.calculatePrice()
print('###################################')
print('Total Price of these two products:',end='')
print('%.2f Dollars'%(m1 + iphone))
# Out:
# ...
# Product Details:
# Name:MacBook
# Product Model:MacBookPro2020
# Hardware Quality:Excellent Hardwares
# Guarantee/ Warranty: Apple Care
# Ram:8GB
# Chip:M1
# Company Details:
# Company Name:Apple
# Founder:MacBook,MacBook,MacBook
# Current CEO:Tim Cook
# Addres Apple Inc,c, 2511 Laguna Blvd, Elk Grove, CA 95758, United States
# ###################################
# ...
# Product Details:
# Name:iPhone
# Product Model:iPhone 12
# Hardware Quality: Excellent Hardwares
# Guarantee/ Warranty: Apple Care
# RAM:8
# Chip:A14
# Company Details:
# Company Name: Apple
# ###################################
# Total Price of these two products:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-3a1d2692157e> in <module>
#      63 print('###################################')
#      64 print('Total Price of these two products:',end='')
# ---> 65 print('%.2f Dollars'%(m1 + iphone))
# ...

# %%
class AppleProduct:

    def _init_(self, name, model, base_price):
        self.name = name
        self.model = model
        self.base_price = base_price
    def companyInfo(self):
        st = ("Company Name: Apple\nFouder: Steve Jobs, Steve Wozniak, Ronald Wayne\nCurrent CEO: Tim Cook\nAddress: Apple Inc, 2511 Laguna Blvd, Elk Grove, CA 95758, United States")
        return st
    def feature(self):
        st = (f"Name: {self.name}\nProduct Model: {self.model}\nHardware Quality: Excellent Hardwares\nGuarantee/ Warranty: Apple Care")
        return st
    def _str_(self):
        print('This is apple product.')
    def calculatePrice(self):
        print('Total Price:', self.base_price)
class MacBookPro2020(AppleProduct):
    def _init_(self,name,model,ram,chip,taxp,base_price = 1299):
        self.base_price = base_price
        self.ram = ram
        self.chip =  chip
        self.taxp = taxp
        super()._init_(name,model,base_price)
        print(f"Product Details:")
    def _str_(self):
        x = super().feature()
        return f"{x} RAM:{self.ram}\nchip:{self.chip}\n{super().companyInfo()}"
    def calculatePrice(self):
        t = (self.base_price * self.taxp)/100
        self.finalp1 = self.base_price + t
        print(f"Calculating Total Price:\nBase Price: {self.base_price}\nTax: {self.taxp}%\nTotal Price: {self.finalp1}")
class iPhone12(AppleProduct):
    def _init_(self,name,model,ram,chip,taxp,base_price = 799):
        self.base_price = base_price
        self.ram = ram
        self.chip =  chip
        self.taxp = taxp
        super()._init_(name,model,base_price)
        print(f"Product Details:")
    def _str_(self):
        x = super().feature()
        return f"{x} RAM:{self.ram}\nchip:{self.chip}\n{super().companyInfo()}"
    def calculatePrice(self):
        t = (self.base_price * self.taxp)/100
        self.finalp2 = self.base_price + t
        print(f"Calculating Total Price:\nBase Price: {self.base_price}\nTax: {self.taxp}%\nTotal Price: {self.finalp2}")
    def _add_(self,other):
        x = self.finalp1 + other.finalp2
        return x
m1 = MacBookPro2020('MacBook','MacBookPro2020', 8, 'M1', 10)
print(m1)
print('====================================')
OUTPUT:Product Details:Name: MacBookProduct Model: MacBookPro2020Hardware Quality: Excellent Hardwares
G uarantee/ Warranty: Apple Care
RAM: 8GB
Chip: M1
Company Details:
Company Name: Apple
Fouder: Steve Jobs, Steve Wozniak, Ronald Wayne
Current CEO: Tim Cook
Address: Apple Inc, 2511 Laguna Blvd, Elk Grove, CA 95758, United
States
====================================
Calculating Total Price:
Base Price: 1299
Tax: 10%
Total Price: 1428.9
###################################
Product Details:
Name: iPhone
Product Model: iPhone 12
Hardware Quality: Excellent Hardwares
Guarantee/ Warranty: Apple Care
RAM: 8GB
Chip: A14
Company Details:
Company Name: Apple
m1.calculatePrice()
print('###################################')
iphone = iPhone12('iPhone', 'iPhone 12', 8,
'A14', 5)
print(iphone)
print('====================================')
iphone.calculatePrice()
print('###################################')
print('Total Price of these two products:
',end='')
print('%.2f Dollars'%(m1 + iphone))

# %%
#quiz -4
class BankAccount:
    all_ac_no = []
    def __init__(self, name, account_no=None):
        self.name = name
        self.__ac_no = account_no
        print("Account created successfully.")

    def setAccountNo(self, ac_no):
        self.all_ac_no.append(ac_no)
        self.__ac_no = ac_no

    def getAccountNo(self):
        return self.__ac_no

    def verifyUser(self):
        if self.__ac_no == None:
            return False
        else:
            return True

    def __str__(self):
        return f"Account Details:\nName: {self.name}\nAccount No: {self.__ac_no}"

class SalaryAccount(BankAccount):
    def __init__(self,name,balance,acn = None):
        self.balance = balance
        self.acn = acn
        if self.acn != None:
            BankAccount.all_ac_no.append(self.acn)
            super().__init__(name,acn)
        if self.acn == None:
            print(f"Cannot append in the account list.")
    def __str__(self):
        x = super().__str__()
        return f"{x} \nBalance:{self.balance}"

    def makeTransaction(self,wd,name1):
        self.wd = wd
        self.name1 = name1
        if super().verifyUser() == False:
            return f"Account number is not set."
        else:
            if self.balance < self.wd:
                return f"You don't have sufficient balance."
            else:
                self.y = self.balance - self.wd
                self.balance = self.y
                return f"Successful transaction! Current balance: {self.y}"

#Driver Code

account1 = SalaryAccount("Md. Rashed", 100)
print("1=========================")
account2 = SalaryAccount("Mrs. Akifa", 200, "acn123")
print("2=========================")
print("All the accounts: ", BankAccount.all_ac_no)
print(account1)
print("3=========================")
print(account1.makeTransaction(150, "Md. Lenin"))
print("4=========================")
account1.setAccountNo("acn124")
print(account1.makeTransaction(150, "Md. Lenin"))
print("5=========================")
print("All the accounts: ", BankAccount.all_ac_no)
print("6=========================")
print(account1.makeTransaction(90, "Md. Lenin"))
print("7=========================")
print(account1)
print("8=========================")
print(account2.makeTransaction(400, "Md. Rohan"))
print("9=========================")
print(account2.makeTransaction(50, "Md. Rohan"))
print("10=========================")
print(account2)
# Out:
# Cannot append in the account list.
# 1=========================
# Account created successfully.
# 2=========================
# All the accounts:  ['acn123']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-82ccf86a6fa5> in <module>
#      56 print("2=========================")
#      57 print("All the accounts: ", BankAccount.all_ac_no)
# ---> 58 print(account1)
#      59 print("3=========================")
#      60 print(account1.makeTransaction(150, "Md. Lenin"))
#
# <ipython-input-14-82ccf86a6fa5> in __str__(self)
#      33             print(f"Cannot append in the account list.")
#      34     def __str__(self):
# ---> 35         x = super().__str__()
#      36         return f"{x} \nBalance:{self.balance}"
#      37
#
# <ipython-input-14-82ccf86a6fa5> in __str__(self)
#      21
#      22     def __str__(self):
# ...

# %%
class BankAccount:
  all_ac_no = []
  def __init__(self, name, account_no=None):
    self.name = name
    self.__ac_no = account_no
    print("Account created successfully.")

  def setAccountNo(self, ac_no):
    self.all_ac_no.append(ac_no)
    self.__ac_no = ac_no

  def getAccountNo(self):
    return self.__ac_no

  def verifyUser(self):
    if self.__ac_no == None:
      return False
    else:
      return True

  def __str__(self):
    return f"Account Details:\nName: {self.name}\nAccount No: {self.__ac_no}"

class SalaryAccount(BankAccount):
  def __init__(self,name,balance,acn = None):
    self.balance = balance
    self.acn = acn
    if self.acn != None:
      BankAccount.all_ac_no.append(self.acn)

    super().__init__(name,acn)
    if self.acn == None:
      print(f"Cannot append in the account list.")
  def __str__(self):
    x = super().__str__()
    return f"{x} \nBalance:{self.balance}"

  def makeTransaction(self,wd,name1):
    self.wd = wd
    self.name1 = name1
    if super().verifyUser() == False:
      return f"Account number is not set."
    else:
      if self.balance < self.wd:
       return f"You don't have sufficient balance."
      else:
        self.y = self.balance - self.wd
        self.balance = self.y

        return f"Successful transaction! Current balance: {self.y}"

#Driver Code

account1 = SalaryAccount("Md. Rashed", 100)
print("1=========================")
account2 = SalaryAccount("Mrs. Akifa", 200, "acn123")
print("2=========================")
print("All the accounts: ", BankAccount.all_ac_no)
print(account1)
print("3=========================")
print(account1.makeTransaction(150, "Md. Lenin"))
print("4=========================")
account1.setAccountNo("acn124")
print(account1.makeTransaction(150, "Md. Lenin"))
print("5=========================")
print("All the accounts: ", BankAccount.all_ac_no)
print("6=========================")
print(account1.makeTransaction(90, "Md. Lenin"))
print("7=========================")
print(account1)
print("8=========================")
print(account2.makeTransaction(400, "Md. Rohan"))
print("9=========================")
print(account2.makeTransaction(50, "Md. Rohan"))
print("10=========================")
print(account2)
# Out:
# Account created successfully.
# Cannot append in the account list.
# 1=========================
# Account created successfully.
# 2=========================
# All the accounts:  ['acn123']
# Account Details:
# Name: Md. Rashed
# Account No: None
# Balance:100
# 3=========================
# Account number is not set.
# 4=========================
# You don't have sufficient balance.
# 5=========================
# All the accounts:  ['acn123', 'acn124']
# 6=========================
# Successful transaction! Current balance: 10
# 7=========================
# Account Details:
# Name: Md. Rashed
# Account No: acn124
# Balance:10
# 8=========================
# You don't have sufficient balance.
# 9=========================
# Successful transaction! Current balance: 150
# 10=========================
# Account Details:
# Name: Mrs. Akifa
# Account No: acn123
# Balance:150

# %%
class BankAccount:
  all_ac_no = []
  def __init__(self, name, account_no=None):
    self.name = name
    self.__ac_no = account_no
    print("Account created successfully.")

  def setAccountNo(self, ac_no):
    self.all_ac_no.append(ac_no)
    self.__ac_no = ac_no

  def getAccountNo(self):
    return self.__ac_no

  def verifyUser(self):
    if self.__ac_no == None:
      return False
    else:
      return True

  def __str__(self):
    return f"Account Details:\nName: {self.name}\nAccount No: {self.__ac_no}"



account1 = SalaryAccount("Md. Rashed", 100)
print("1=========================")
account2 = SalaryAccount("Mrs. Akifa", 200, "acn123")
print("2=========================")
print("All the accounts: ", BankAccount.all_ac_no)
print(account1)
print("3=========================")
print(account1.makeTransaction(150, "Md. Lenin"))
print("4=========================")
account1.setAccountNo("acn124")
print(account1.makeTransaction(150, "Md. Lenin"))
print("5=========================")
print("All the accounts: ", BankAccount.all_ac_no)
print("6=========================")
print(account1.makeTransaction(90, "Md. Lenin"))
print("7=========================")
print(account1)
print("8=========================")
print(account2.makeTransaction(400, "Md. Rohan"))
print("9=========================")
print(account2.makeTransaction(50, "Md. Rohan"))
print("10=========================")
print(account2)

# %%
class Monster:
    monsterCount = 0
    def __init__(self,name,power):
        self.name = name
        self.power = power
        Monster.monsterCount += 1
    def get_details(self):
        return f"Name:{self.name}\nPower:{self.power}"

    def attack(self,*args):
        if len(args) == 0:
            return f"No monsters to attack"
        elif len(args) == 1:
            return f"Attack successful.Godzilla defeated by Hydra"
        elif len(args) == 2:
            return f"Cannot attack Hydra.It's not alive.Attack unsuccessful.Godzilla was defeated by Kingkong."

monster1 = Monster('Godzilla', 40)
monster2 = Monster('Hydra', 30)
monster3 = Monster('KingKong', 50)
print(f"Number of monsters alive:{Monster.monsterCount}")
print('1--------------------------------')
print(monster1.get_details())
print('2--------------------------------')
print(monster2.get_details())
print('3--------------------------------')
print(monster3.get_details())
print('4--------------------------------')
monster1.attack()
print('5--------------------------------')
monster1.attack(monster2)
print('6--------------------------------')
monster1.attack(monster2, monster3)
print('7--------------------------------')
print(f"Number of monsters alive:{Monster.monsterCount}")
print('8--------------------------------')
print(monster2.get_details())
print('9--------------------------------')
monster2.attack(monster1)
# Out:
# Number of monsters alive:3
# 1--------------------------------
# Name:Godzilla
# Power:40
# 2--------------------------------
# Name:Hydra
# Power:30
# 3--------------------------------
# Name:KingKong
# Power:50
# 4--------------------------------
# 5--------------------------------
# 6--------------------------------
# 7--------------------------------
# Number of monsters alive:3
# 8--------------------------------
# Name:Hydra
# Power:30
# 9--------------------------------
# 'Attack successful.Godzilla defeated by Hydra'

# %% [markdown]
# # New task from here

# %%
#task-1
class Student:
    ID = 0
    def __init__(self,name,department,age,cgpa):
        self.name = name
        self.department = department
        self.age = age
        self.cgpa = cgpa
        Student.ID += 1
    def showDetails(self):
        print(f"ID:{Student.ID}")
        print(f"Name:{self.name}")
        print(f"Department:{self.department}")
        print(f"Age:{self.age}")
        print(f"CGPA:{self.cgpa}")
    @classmethod
    def from_String(self,string):
        name,dept,age,cgpa = string.split("-")
        return Student(name,dept,age,cgpa)
s1 = Student("Samin", "CSE", 21, 3.91)
s1.showDetails()
print("-----------------------")
s2 = Student("Fahim", "ECE", 21, 3.85)
s2.showDetails()
print("-----------------------")
s3 = Student("Tahura", "EEE", 22, 3.01)
s3.showDetails()
print("-----------------------")
s4 = Student.from_String("Sumaiya-BBA-23-3.96")
s4.showDetails()
# Out:
# ID:1
# Name:Samin
# Department:CSE
# Age:21
# CGPA:3.91
# -----------------------
# ID:2
# Name:Fahim
# Department:ECE
# Age:21
# CGPA:3.85
# -----------------------
# ID:3
# Name:Tahura
# Department:EEE
# Age:22
# CGPA:3.01
# -----------------------
# ID:4
# Name:Sumaiya
# Department:BBA
# Age:23
# CGPA:3.96

# %%
#task-2
class Assassin:
    number = 0
    def __init__(self,name,rate):
        self.name = name
        self.rate = rate
        Assassin.number += 1
    def printDetails(self):
        print(f"Name:{self.name}")
        print(f"Success rate:{self.rate}%")
        print(f"Total number of Assssin:{Assassin.number}")
    @classmethod
    def failureRate(cls,name,rate):
        var = 100 - rate
        return cls(name,var)
    @classmethod
    def failurePercentage(cls,name,rate):
        var = 100 - int(rate.replace("%",""))
        return cls(name,var)
john_wick = Assassin('John Wick', 100)
john_wick.printDetails()
print('================================')
nagisa = Assassin.failureRate("Nagisa", 20)
nagisa.printDetails()
print('================================')
akabane = Assassin.failurePercentage("Akabane", "10%")
akabane.printDetails()
# Out:
# Name:John Wick
# Success rate:100%
# Total number of Assssin:1
# ...
# Name:Nagisa
# Success rate:80%
# Total number of Assssin:2
# ...
# Name:Akabane
# Success rate:90%
# Total number of Assssin:3

# %%
#task-3
class Passenger:
    count = 0
    def __init__(self,name):
        self.name = name
        self.fare = 450
        Passenger.count += 1
    def set_bag_weight(self,weight):
        self.weight = weight
        if 21 <= self.weight <= 50:
            self.fare += 50
        elif self.weight > 50:
            self.fare += 100
    def printDetail(self):
        print(f"Name:{self.name}")
        print(f"Bus Fare:{self.fare}")
print("Total Passenger:", Passenger.count)
p1 = Passenger("Jack")
p1.set_bag_weight(90)
p2 = Passenger("Carol")
p2.set_bag_weight(10)
p3 = Passenger("Mike")
p3.set_bag_weight(25)
print("=========================")
p1.printDetail()
print("=========================")
p2.printDetail()
print("=========================")
p3.printDetail()
print("=========================")
print("Total Passenger:", Passenger.count)
# Out:
# Total Passenger: 0
# ...
# Name:Jack
# Bus Fare:550
# ...
# Name:Carol
# Bus Fare:450
# ...
# Name:Mike
# Bus Fare:500
# ...
# Total Passenger: 3

# %%
#task-4
class Travel:
    count = 0
    def __init__(self,source,destination,time = 1):
        self.source = source
        self.destination = destination
        self.time = time
        Travel.count += 1
    def display_travel_info(self):
        return f"Source:{self.source}\nDestination:{self.destination}\nFlight Time:{self.time}:00"
    def set_time(self,time):
        self.time = time
    def set_destination(self,country1):
        self.country1 = country1
    def set_source(self,country2):
        self.country2 = country2



print("No. of Traveller =", Travel.count)
print("=======================")
t1 = Travel("Dhaka","India")
print(t1.display_travel_info())
print("=======================")
t2 = Travel("Kuala Lampur","Dhaka")
t2.set_time(23)
print(t2.display_travel_info())
print("=======================")
t3 = Travel("Dhaka","New_Zealand")
t3.set_time(15)
t3.set_destination("Germany")
print(t3.display_travel_info())
print("=======================")
t4 = Travel("Dhaka","India")
t4.set_time(9)
t4.set_source("Malaysia")
t4.set_destination("Canada")
print(t4.display_travel_info())
print("=======================")
print("No. of Traveller =", Travel.count)
# Out:
# No. of Traveller = 0
# ...
# Source:Dhaka
# Destination:India
# Flight Time:1:00
# ...
# Source:Kuala Lampur
# Destination:Dhaka
# Flight Time:23:00
# ...
# Source:Dhaka
# Destination:New_Zealand
# Flight Time:15:00
# ...
# Source:Dhaka
# Destination:India
# Flight Time:9:00
# ...
# No. of Traveller = 4

# %%
#task-9
class Student:
    total_student = 0
    brac_student = 0
    other_student = 0
    Student.total_student += 1
    def __init__(self,name,dept):
        self.name = name
        self.dept = dept
        self.institution = "BRAC University"
    def individualDetail(self):
        print(f"Name:{self.name}")
        print(f"Department:{self.dept}")
        print(f"Institution:{self.institution}")
    @classmethod
    def printDetails(cls):
        return f"Total Student:{Student.total_student}\nBRAC University Student(s):{brac_student}\nOther institutiion student(s):{other_student}"
    @classmethod
    def createStudent(cls):
        return




Student.printDetails()
print('#########################')

mikasa = Student('Mikasa Ackerman', "CSE")
mikasa.individualDetail()
print('------------------------------------------')
Student.printDetails()

print('========================')

harry = Student.createStudent('Harry Potter', "Defence Against Dark Arts", "Hogwarts School")
harry.individualDetail()
print('-------------------------------------------')
Student.printDetails()

print('=========================')

levi = Student.createStudent("Levi Ackerman", "CSE")
levi.individualDetail()
print('--------------------------------------------')
Student.printDetails()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-8ab6cd35cc95> in <module>
#       1 #task-9
# ----> 2 class Student:
#       3     total_student = 0
#       4     brac_student = 0
#       5     other_student = 0
#
# <ipython-input-22-8ab6cd35cc95> in Student()
#       4     brac_student = 0
#       5     other_student = 0
# ----> 6     Student.total_student += 1
#       7     def __init__(self,name,dept):
#       8         self.name = name
#
# NameError: name 'Student' is not defined

# %%
#task-5
class Employee:
    def __init__(self,name,workingPeriod):
        self.name = name
        self.workingPeriod = workingPeriod
    @classmethod
    def employeeByJoiningYear(cls,name,year):
        return




employee1 = Employee('Dororo', 3)
employee2 = Employee.employeeByJoiningYear('Harry', 2016)
print(employee1.workingPeriod)
print(employee2.workingPeriod)
print(employee1.name)
print(employee2.name)
print(Employee.experienceCheck(2, "male"))
print(Employee.experienceCheck(3, "female"))

# %%
#task-1
class Student:
    ID = 0
    def __init__(self,name,department,age,cgpa):
        self.name = name
        self.department = department
        self.age = age
        self.cgpa = cgpa
        Student.ID += 1
    def showDetails(self):
        print(f"ID:{Student.ID}")
        print(f"Name:{self.name}")
        print(f"Department:{self.department}")
        print(f"Age:{self.age}")
        print(f"CGPA:{self.cgpa}")
    @classmethod
    def from_String(cls,string):
        name,dept,age,cgpa = string.split("-")
        return cls(name,dept,age,cgpa)

s1 = Student("Samin", "CSE", 21, 3.91)
s1.showDetails()
print("-----------------------")
s2 = Student("Fahim", "ECE", 21, 3.85)
s2.showDetails()
print("-----------------------")
s3 = Student("Tahura", "EEE", 22, 3.01)
s3.showDetails()
print("-----------------------")
s4 = Student.from_String("Sumaiya-BBA-23-3.96")
s4.showDetails()
# Out:
# ID:1
# Name:Samin
# Department:CSE
# Age:21
# CGPA:3.91
# -----------------------
# ID:2
# Name:Fahim
# Department:ECE
# Age:21
# CGPA:3.85
# -----------------------
# ID:3
# Name:Tahura
# Department:EEE
# Age:22
# CGPA:3.01
# -----------------------
# ID:4
# Name:Sumaiya
# Department:BBA
# Age:23
# CGPA:3.96

# %%
#task-2
class Assassin:
    count = 0
    def __init__(self,name,success_rate):
        self.name = name
        self.success_rate = success_rate
        Assassin.count += 1
    @classmethod
    def failureRate(cls,name,rate):
        var = 100 - rate
        return cls(name,rate)
    @classmethod
    def failurePercentage(cls,name,rate):
        var = 100 - int(rate.replace("%",""))
        return cls(name,rate)
    def printDetails(self):
        print(f"Name:{self.name}")
        print(f"Success rate:{self.success_rate}%")
        print(f"Total number of Assassin:{Assassin.count}")



john_wick = Assassin('John Wick', 100)
john_wick.printDetails()
print('================================')
nagisa = Assassin.failureRate("Nagisa", 20)
nagisa.printDetails()
print('================================')
akabane = Assassin.failurePercentage("Akabane", "10%")
akabane.printDetails()
# Out:
# Name:John Wick
# Success rate:100%
# Total number of Assassin:1
# ...
# Name:Nagisa
# Success rate:20%
# Total number of Assassin:2
# ...
# Name:Akabane
# Success rate:10%%
# Total number of Assassin:3

# %%
#task-3
class Passenger:
    count = 0
    def __init__(self,name):
        self.name = name
        self.fare = 450
        Passenger.count += 1
    def set_bag_weight(self,weight):
        self.weight = weight
        if self.weight <= 20:
            pass
        elif 21<=self.weight<=50:
            self.fare += 50
        elif self.weight > 50:
            self.fare += 100
    def printDetail(self):
        print(f"Name:{self.name}")
        print(f"Bus Fare:{self.fare}taka")
print("Total Passenger:", Passenger.count)
p1 = Passenger("Jack")
p1.set_bag_weight(90)
p2 = Passenger("Carol")
p2.set_bag_weight(10)
p3 = Passenger("Mike")
p3.set_bag_weight(25)
print("=========================")
p1.printDetail()
print("=========================")
p2.printDetail()
print("=========================")
p3.printDetail()
print("=========================")
print("Total Passenger:", Passenger.count)
# Out:
# Total Passenger: 0
# ...
# Name:Jack
# Bus Fare:550taka
# ...
# Name:Carol
# Bus Fare:450taka
# ...
# Name:Mike
# Bus Fare:500taka
# ...
# Total Passenger: 3

# %%
#task-4
class Travel:
    count = 0
    def __init__(self,source,destination):
        self.source = source
        self.destination = destination
        self.time = 1
        Travel.count += 1
    def set_time(self,time):
        self.time = time
    def set_source(self,source):
        self.source = source
    def set_destination(self,destination):
        self.destination = destination
    def display_travel_info(self):
        return f"Source:{self.source}\nDestination:{self.destination}\nFlight Time:{self.time}:00"

    # def display_travel_info(self):
    #     output = ''
    #     output += 'Source: ' + self.source + '\n'
    #     output += 'Destination: ' + self.destination + '\n'
    #     output += 'Flight Time: ' + str(self.time) + ':00'
    #     return output

print("No. of Traveller =", Travel.count)
print("=======================")
t1 = Travel("Dhaka","India")
print(t1.display_travel_info())
print("=======================")
t2 = Travel("Kuala Lampur","Dhaka")
t2.set_time(23)
print(t2.display_travel_info())
print("=======================")
t3 = Travel("Dhaka","New_Zealand")
t3.set_time(15)
t3.set_destination("Germany")
print(t3.display_travel_info())
print("=======================")
t4 = Travel("Dhaka","India")
t4.set_time(9)
t4.set_source("Malaysia")
t4.set_destination("Canada")
print(t4.display_travel_info())
print("=======================")
print("No. of Traveller =", Travel.count)
# Out:
# No. of Traveller = 0
# ...
# Source:Dhaka
# Destination:India
# Flight Time:1:00
# ...
# Source:Kuala Lampur
# Destination:Dhaka
# Flight Time:23:00
# ...
# Source:Dhaka
# Destination:Germany
# Flight Time:15:00
# ...
# Source:Malaysia
# Destination:Canada
# Flight Time:9:00
# ...
# No. of Traveller = 4

# %%
#task-5
class Employee:
    def __init__(self,name,workingPeriod):
        self.name = name
        self.workingPeriod = workingPeriod
    @classmethod
    def employeeByJoiningYear(cls,name,year):
        return cls(name,2022-year)
    @classmethod
    def experienceCheck(cls,workingPeriod,gender):
        if workingPeriod < 3:
            if gender == "male":
                return "He is not experienced"
            else:
                return "She is not experienced"
        else:
            if gender == "male":
                return "He is experienced"
            else:
                return "She is experienced"
employee1 = Employee('Dororo', 3)
employee2 = Employee.employeeByJoiningYear('Harry', 2016)
print(employee1.workingPeriod)
print(employee2.workingPeriod)
print(employee1.name)
print(employee2.name)
print(Employee.experienceCheck(2, "male"))
print(Employee.experienceCheck(3, "female"))
# Out:
# 3
# 6
# Dororo
# Harry
# He is not experienced
# She is experienced

# %%
#taak-7
class Cat:
    Number_of_cats = 0
    def __init__(self,color,action):
        self.color = color
        self.action = action
        Cat.Number_of_cats += 1
    def printCat(self):
        print(f"{self.color} cat is {self.action}")
    def changeColor(self,color):
        self.color = color
    @classmethod
    def no_parameter(cls):
        return Cat("White","action")
    @classmethod
    def first_parameter(cls,color):
        return Cat(color,"action")
    @classmethod
    def second_parameter(cls,action):
        return Cat("Grey",action)



print("Total number of cats:", Cat.Number_of_cats)
c1 = Cat.no_parameter()
c2 = Cat.first_parameter("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c5 = Cat.second_parameter("playing")
print("=======================")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c5.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
print("=======================")
print("Total number of cats:", Cat.Number_of_cats)
# Out:
# Total number of cats: 0
# ...
# White cat is action
# Black cat is action
# Brown cat is jumping
# Red cat is purring
# Grey cat is playing
# Blue cat is action
# Purple cat is jumping
# ...
# Total number of cats: 5

# %%
#task-8
class Cylinder:
    radius = 5
    height = 18
    def __init__(self,radius,height):
        self.radius = radius
        self.height = height
    @classmethod
    def area(cls,radius,height):
        x =




c1 = Cylinder(0,0)
Cylinder.area(c1.radius,c1.height)
Cylinder.volume(c1.radius,c1.height)
print("===============================")
c2 = Cylinder.swap(8,3)
c2.area(c2.radius,c2.height)
c2.volume(c2.radius,c2.height)
print("===============================")
c3 = Cylinder.changeFormat("7-13")
c3.area(c3.radius,c3.height)
c3.volume(c3.radius,c3.height)
print("===============================")
Cylinder(0.3,5.56).area(Cylinder.radius,Cylinder.height)
print("===============================")
Cylinder(3,5).volume(Cylinder.radius,Cylinder.height)

# %%
#task-9
class Student:
    total_student = 0
    brac_student = 0
    other_student = 0
    def __init__(self,name,dept):
        self.name = name
        self.dept = dept
        self.institution = "BRAC University"
        Student.total_student += 1
        Student.brac_student += 1
        Student.other_student += 1
    def individualDetail(self):
        print(f"Name:{self.name}")
        print(f"Department:{self.dept}")
        print(f"Institution:{self.institution}")
    def printDetails(self):
        print(f"Total Student(s):{Student.total_student}")
        print(f"BRAC University Student(s):{Student.brac_student}")
        print(f"Other Institution Student(s):{Student.other_student}")
    @classmethod
    def createStudent(cls,name,dept,institute):
        return cls(name,dept,institute)

Student.printDetails()
print('#########################')

mikasa = Student('Mikasa Ackerman', "CSE")
mikasa.individualDetail()
print('------------------------------------------')
Student.printDetails()

print('========================')

harry = Student.createStudent('Harry Potter', "Defence Against Dark Arts", "Hogwarts School")
harry.individualDetail()
print('-------------------------------------------')
Student.printDetails()

print('=========================')

levi = Student.createStudent("Levi Ackerman", "CSE")
levi.individualDetail()
print('--------------------------------------------')
Student.printDetails()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-6b1580e34b90> in <module>
#      23         return cls(name,dept,institute)
#      24
# ---> 25 Student.printDetails()
#      26 print('#########################')
#      27
#
# TypeError: printDetails() missing 1 required positional argument: 'self'

# %%
class Student:
    def __init__(self,name = "Just a student",dept = "nothing"):
        self.__name = name
        self.__department = department
    def set_department(self,dept):
        self.__department = dept
    def get_name(self):
        return self.__name
    def set_name(self):
        self.__name = name
    def __str__(self):
        return "Name:"+self.__name + "Department:" + self.__department

class BBA_Student(Student):
    def __init__(self,name = "default"):
        super().__init__(name,)




print(BBA_Student())
print(BBA_Student('Humpty Dumpty'))
print(BBA_Student('Little Bo Peep'))

# %%
#task-3
class Tournament:
    def __init__(self,name='Default'):
        self.__name = name
    def set_name(self,name):
        self.__name = name
    def get_name(self):
        return self.__name
class Cricket_Tournament:
    def __init__(self,name = "Default",teams = 0,Type = "No type"):
        self.name = name
        self.teams = teams
        self.Type = Type
    def detail(self):
        return f"Cricket Tournament Name:{self.name}\nNumber of Teams:{self.teams}\nType:{self.Type}"

class Tennis_Tournament:
    def __init__(self,name,players):
        self.name = name
        self.players = players
    def detail(self):
        return f"Tennis Tournament Name:{self.name}\nNumber of players:{self.players}"

ct1 = Cricket_Tournament()
print(ct1.detail())
print("-----------------------")
ct2 = Cricket_Tournament("IPL",10,"t20")
print(ct2.detail())
print("-----------------------")
tt = Tennis_Tournament("Roland Garros",128)
print(tt.detail())
# Out:
# Cricket Tournament Name:Default
# Number of Teams:0
# Type:No type
# -----------------------
# Cricket Tournament Name:IPL
# Number of Teams:10
# Type:t20
# -----------------------
# Tennis Tournament Name:Roland Garros
# Number of players:128

# %%
#inheritence use
class Tournament:
    def __init__(self,name='Default'):
        self.__name = name
    def set_name(self,name):
        self.__name = name
    def get_name(self):
        return self.__name
class Cricket_Tournament(Tournament):
    def __init__(self,name= "Default",teams = 0,Type="No type"):
        super().__init__(name)
        self.teams = teams
        self.Type = Type
    def detail(self):
        return f"Cricket Tournament Name:{self.get_name()}\nNumber of Teams:{self.teams}\nType:{self.Type}"
class Tennis_Tournament(Tournament):
    def __init__(self,name,players):
        super().__init__(name)
        self.players = players
    def detail(self):
        return f"Tennis Tournament Name:{self.get_name()}\nNumber of Players:{self.players}"
ct1 = Cricket_Tournament()
print(ct1.detail())
print("-----------------------")
ct2 = Cricket_Tournament("IPL",10,"t20")
print(ct2.detail())
print("-----------------------")
tt = Tennis_Tournament("Roland Garros",128)
print(tt.detail())
# Out:
# Cricket Tournament Name:Default
# Number of Teams:0
# Type:No type
# -----------------------
# Cricket Tournament Name:IPL
# Number of Teams:10
# Type:t20
# -----------------------
# Tennis Tournament Name:Roland Garros
# Number of Players:128

# %%
class Product:
    def __init__(self,id, title, price):
        self.__id = id
        self.__title = title
        self.__price = price
    def get_id_title_price(self):
        return "ID: "+str(self.__id)+" Title:"+str(self.__title)+"Price: "+str(self.__price)
class Book(Product):
    def __init__(self,id,price,title,isbn,publisher):
        super().__init__(id,title,price)
        self.isbn = isbn
        self.publisher = publisher
    def printDetail(self):
        return f"{self.get_id_title_price()}\nISBN:{self.isbn} Publisher:{self.publisher}"

class CD(Product):
    def __init__(self,id,title,price,band,duration,genre):
        super().__init__(id,title,price)
        self.band = band
        self.duration = duration
        self.genre = genre
    def printDetail(self):
        return f"{self.get_id_title_price()}\nBand:{self.band} Duration:{self.duration}minutes\nGenre:{self.genre}"

book = Book(1,"The Alchemist",500,"97806","HarperCollins")
print(book.printDetail())
print("-----------------------")
cd = CD(2,"Shotto",300,"Warfaze",50,"Hard Rock")
print(cd.printDetail())
# Out:
# ID: 1 Title:500Price: The Alchemist
# ISBN:97806 Publisher:HarperCollins
# -----------------------
# ID: 2 Title:ShottoPrice: 300
# Band:Warfaze Duration:50minutes
# Genre:Hard Rock

# %%
#task-3
class Tournament:
    def __init__(self,name='Default'):
        self.__name = name
    def set_name(self,name):
        self.__name = name
    def get_name(self):
        return self.__name
class Cricket_Tournament:
    def __init__(self,name="Default",teams=0,Type="No type"):
        self.name = name
        self.teams = teams
        self.Type = Type
    def detail(self):
        return f"Cricket Tournament Name:{self.name}\nNumber of Teams:{self.teams}\Type:{self.Type}"
class Tennis_Tournament:
    def __init__(self,name,players):
        self.name = name
        self.players = players
    def detail(self):
        return f"Tennis Tournament Name:{self.name}\Number of Players:{self.players}"

ct1 = Cricket_Tournament()
print(ct1.detail())
print("-----------------------")
ct2 = Cricket_Tournament("IPL",10,"t20")
print(ct2.detail())
print("-----------------------")
tt = Tennis_Tournament("Roland Garros",128)
print(tt.detail())
# Out:
#   File "<ipython-input-4-a6c6be820167>", line 21
#     return f"Tennis Tournament Name:{self.name}\Number of Players:{self.players}"
#            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 0-1: malformed \N character escape

# %%
#inheritence
class Tournament:
    def __init__(self,name='Default'):
        self.__name = name
    def set_name(self,name):
        self.__name = name
    def get_name(self):
        return self.__name
class Cricket_Tournament(Tournament):
    def __init__(self,name = "Default",teams = 0,Type = "No type"):
        super().__init__(name)
        self.teams = teams
        self.Type = Type
    def detail(self):
        return f"Cricket Tournament Name:{super().get_name()}\nNumber of Teams:{self.teams}\nType:{self.Type}"
class Tennis_Tournament(Tournament):
    def __init__(self,name,players):
        super().__init__(name)
        self.players = players
    def detail(self):
        return f"Tennis Tournament Name:{super().get_name()}\nNumber of Players:{self.players}"
ct1 = Cricket_Tournament()
print(ct1.detail())
print("-----------------------")
ct2 = Cricket_Tournament("IPL",10,"t20")
print(ct2.detail())
print("-----------------------")
tt = Tennis_Tournament("Roland Garros",128)
print(tt.detail())
# Out:
# Cricket Tournament Name:Default
# Number of Teams:0
# Type:No type
# -----------------------
# Cricket Tournament Name:IPL
# Number of Teams:10
# Type:t20
# -----------------------
# Tennis Tournament Name:Roland Garros
# Number of Players:128

# %%
#task-4
class Product:
    def __init__(self,id, title, price):
        self.__id = id
        self.__title = title
        self.__price = price
    def get_id_title_price(self):
        return "ID: "+str(self.__id)+" Title:"+str(self.__title)+"Price: "+str(self.__price)
class Book(Product):
    def __init__(self,id,title,price,isbn,publisher):
        super().__init__(id,title,price)
        self.isbn = isbn
        self.publisher = publisher
    def printDetail(self):
        return f"{super().get_id_title_price()}\nISBN:{self.isbn} Publisher:{self.publisher}"
class CD(Product):
    def __init__(self,id,title,price,band,duration,genre):
        super().__init__(id,title,price)
        self.band = band
        self.duration = duration
        self.genre = genre
    def printDetail(self):
        return f"{super().get_id_title_price()}\nBand:{self.band} Duration:{self.duration}minutes\nGenre:{self.genre}"

book = Book(1,"The Alchemist",500,"97806","HarperCollins")
print(book.printDetail())
print("-----------------------")
cd = CD(2,"Shotto",300,"Warfaze",50,"Hard Rock")
print(cd.printDetail())
# Out:
# ID: 1 Title:The AlchemistPrice: 500
# ISBN:97806 Publisher:HarperCollins
# -----------------------
# ID: 2 Title:ShottoPrice: 300
# Band:Warfaze Duration:50minutes
# Genre:Hard Rock

# %%
#task-5
class Animal:
    def __init__(self,sound):
        self.__sound = sound

    def makeSound(self):
        return self.__sound
class Dog(Animal):
    def __init__(self,sound):
        super().__init__(sound)
    def printSound(self):
        print(f"bark")
class Cat(Animal):
    def __init__(self,sound):
        super().__init__(sound)
    def printSound(self):
        print(f"Meow")
class Printer:
    def printSound(self, a):
        print(a.makeSound())
d1 = Dog('bark')
c1 = Cat('meow')
a1 = Animal('Animal does not make sound')
pr = Printer()
pr.printSound(a1)
pr.printSound(c1)
pr.printSound(d1)
# Out:
# Animal does not make sound
# meow
# bark

# %%
#task-6
class Shape:

  def __init__(self, name='Default', height=0, base=0):
    self.area = 0
    self.name = name
    self.height = height
    self.base = base

  def get_height_base(self):
    return "Height: "+str(self.height)+",Base: "+str(self.base)
class triangle(Shape):
    def __init__(self,name = "Default",height = 0,base = 0):
        super().__init__(name,height,base)
    def calcArea(self):
        self.area = 0.5 * self.height * self.base
        return self.area
    def printDetail(self):
        return f"Shape name:{self.name}{super().get_height_base()}\nArea:{self.area}"
class trapezoid(Shape):
    def __init__(self,name,height,base,side_A):
        super().__init__(name,height,base)
        self.side_A = side_A
    def calcArea(self):
        self.area = 0.5 * (self.base + self.side_A) * self.height
        return self.area
    def printDetail(self):
        return f"Shape name:{self.name}{super().get_height_base()}\nArea:{self.area}"
tri_default = triangle()
tri_default.calcArea()
print(tri_default.printDetail())
print('--------------------------')
tri = triangle('Triangle', 10, 5)
tri.calcArea()
print(tri.printDetail())
print('---------------------------')
trap = trapezoid('Trapezoid', 10, 6, 4)
trap.calcArea()
print(trap.printDetail())
# Out:
# Shape name:DefaultHeight: 0,Base: 0
# Area:0.0
# --------------------------
# Shape name:TriangleHeight: 10,Base: 5
# Area:25.0
# ---------------------------
# Shape name:TrapezoidHeight: 10,Base: 6
# Area:50.0

# %%
#task-7
class SportsPerson:

  def __init__(self, team_name, name, role):
    self.__team = team_name
    self.__name = name
    self.role = role
    self.earning_per_match = 0

  def get_name_team(self):
    return 'Name: '+self.__name+', Team Name: ' +self.__team
class Player(SportsPerson):
    def __init__(self,team_name,name,role,goal,total_play):
        super().__init__(team_name,name,role)
        self.goal = goal
        self.total_play = total_play
        #self.x = (self.total_goal * 1000)+(self.total_match * 10)
    def calculate_ratio(self):
        self.goal_ratio = self.goal / self.total_play
    def print_details(self):
        self.y = (self.goal*1000) + (self.total_play *10)
        print(f"{super().get_name_team()}\nTeam Role:{self.role}\nTotal Goal:{self.goal},Total Played:{self.total_play}\nGoal Ratio:{self.goal_ratio}\nMatch Earning:{self.y}k")
class Manager(SportsPerson):
    def __init__(self,name,team_name,role,win):
        super().__init__(name,team_name,role)
        self.win = win
    def print_details(self):
        self.y = self.win * 1000
        #self.y = (self.goal*1000) + (self.total_play *10)
        print(f"{super().get_name_team()}\nTeam Role:{self.role}\nTotal Win:{self.win}\nMatch Earning:{self.y}k")
player_one = Player('Juventus', 'Ronaldo', 'Striker', 25, 32)
player_one.calculate_ratio()
player_one.print_details()
print('------------------------------------------')
manager_one = Manager('Real Madrid', 'Zidane', 'Manager', 25)
manager_one.print_details()
# Out:
# Name: Ronaldo, Team Name: Juventus
# Team Role:Striker
# Total Goal:25,Total Played:32
# Goal Ratio:0.78125
# Match Earning:25320k
# ------------------------------------------
# Name: Zidane, Team Name: Real Madrid
# Team Role:Manager
# Total Win:25
# Match Earning:25000k

# %%
#task-7
class Football:
    def __init__(self, team_name, name, role):
        self.__team = team_name
        self.__name = name
        self.role = role
        self.earning_per_match = 0
    def get_name_team(self):
        return 'Name: '+self.__name+', Team Name: ' +self.__team

class Player(Football):
    def __init__(self,team_name,name,role,goal,played):
        super().__init__(team_name,name,role)
        self.goal = goal
        self.played = played
    def calculate_ratio(self):
        self.ratio = self.goal / self.played
        return self.ratio
    def print_details(self):
        self.earning = (self.goal * 1000) + (self.played * 10)
        print(f"{super().get_name_team()}\nTeam Role:{self.role}\nTotal Goal:{self.goal},Total played:{self.played}\nGoal Ratio:{self.ratio}\nMatch Earning:{self.earning}k")

class Manager(Football):
    def __init__(self,name,team_name,role,win):
        super().__init__(name,team_name,role)
        self.win = win
        self.role = role
    def print_details(self):
        self.earning = (self.win *1000)
        print(f"{super().get_name_team()}\nTeam Role:{self.role}\nTotal Win:{self.win}\nMatch Earning:{self.earning}k")
player_one = Player('Juventus', 'Ronaldo', 'Striker', 25, 32)
player_one.calculate_ratio()
player_one.print_details()
print('------------------------------------------')
manager_one = Manager('Real Madrid', 'Zidane', 'Manager', 25)
manager_one.print_details()
# Out:
# Name: Ronaldo, Team Name: Juventus
# Team Role:Striker
# Total Goal:25,Total played:32
# Goal Ratio:0.78125
# Match Earning:25320k
# ------------------------------------------
# Name: Zidane, Team Name: Real Madrid
# Team Role:Manager
# Total Win:25
# Match Earning:25000k

# %%
class Department:
    def __init__(self, s):
        self.semester = s
        self.name = "Default"
        self.id = -1

    def student_info(self):
        print("Name:", self.name)
        print("ID:", self.id)

    def courses(self, c1, c2, c3):
        print("No courses Approved yet!")
class CSE(Department):
    def __init__(self,name,id,semester):
        super().__init__(semester)
        self.name = name
        self.id = id
        self.dept = "CSE"
    def student_info(self):
        super().student_info()
    def courses(self,c1,c2,c3):
        self.c1 = c1
        self.c2 = c2
        self.c3 = c3
        print(f"Courses Approved to this {self.dept} student in {self.semester} semester:")
        print(f"{c1}\n{c2}\n{c3}")
class EEE(Department):
    def __init__(self,name,id,semester):
        super().__init__(semester)
        self.name = name
        self.id = id
        self.dept = "EEE"
    def student_info(self):
        super().student_info()
    def courses(self,c1,c2,c3):
        self.c1 = c1
        self.c2 = c2
        self.c3 = c3
        print(f"Courses Approved to this {self.dept} student in {self.semester} semester:")
        print(f"{c1}\n{c2}\n{c3}")
s1 = CSE("Rahim", 16101328,"Spring2016")
s1.student_info()
s1.courses("CSE110", "MAT110", "ENG101")
print("==================")
s2 = EEE("Tanzim", 18101326, "Spring2018")
s2.student_info()
s2.courses("Mat110", "PHY111", "ENG101")
print("==================")
s3 = CSE("Rudana", 18101326, "Fall2017")
s3.student_info()
s3.courses("CSE111", "PHY101", "MAT120")
print("==================")
s4 = EEE("Zainab", 19201623, "Summer2019")
s4.student_info()
s4.courses("EEE201", "PHY112", "MAT120")
# Out:
# Name: Rahim
# ID: 16101328
# Courses Approved to this CSE student in Spring2016 semester:
# CSE110
# MAT110
# ENG101
# ...
# Name: Tanzim
# ID: 18101326
# Courses Approved to this EEE student in Spring2018 semester:
# Mat110
# PHY111
# ENG101
# ...
# Name: Rudana
# ID: 18101326
# Courses Approved to this CSE student in Fall2017 semester:
# CSE111
# PHY101
# MAT120
# ...
# Name: Zainab
# ID: 19201623
# Courses Approved to this EEE student in Summer2019 semester:
# EEE201
# PHY112
# MAT120

# %%
#task-5
class Exam:
    def __init__(self,marks):
        self.marks = marks
        self.time = 60

    def examSyllabus(self):
        return "Maths , English"
    def examParts(self):
        return "Part 1 - Maths\nPart 2 - English\n"
class ScienceExam(Exam):
    def __init__(self,marks,time,*subjects):
        super().__init__(marks)
        self.time = time
        self.subjects = subjects
    def examSyllabus(self):
        output = super().examSyllabus()
        for i in self.subjects:
            output += "," + i
        return output
    def examParts(self):
        output = super().examParts()
        for i in self.subjects:
            output += f"Part{self.subjects.index(i)+3}-{i}\n"
            #output += f'Part {self.subjects.index(sub)+3} - {sub}\n'
            return output
    def __str__(self):
        return f"Marks:{self.marks} Time:{self.time} minutes Number of Parts:{len(self.subjects)+2}"

engineering = ScienceExam(100,90,"Physics","HigherMaths")
print(engineering)
print('----------------------------------')
print(engineering.examSyllabus())
print(engineering.examParts())
print('==================================')
architecture = ScienceExam(100,120,"Physics","HigherMaths","Drawing")
print(architecture)
print('----------------------------------')
print(architecture.examSyllabus())
print(architecture.examParts())
# Out:
# Marks:100 Time:90 minutes Number of Parts:4
# ----------------------------------
# Maths , English,Physics,HigherMaths
# Part 1 - Maths
# Part 2 - English
# Part3-Physics
#
# ...
# Marks:100 Time:120 minutes Number of Parts:5
# ----------------------------------
# Maths , English,Physics,HigherMaths,Drawing
# Part 1 - Maths
# Part 2 - English
# Part3-Physics

# %%
#task-6
class Shape3D:

  pi = 3.14159
  def __init__(self, name = 'Default', radius = 0):
    self._area = 0
    self._name = name
    self._height = 'No need'
    self._radius = radius

  def calc_surface_area(self):
    return 2 * Shape3D.pi * self._radius

  def __str__(self):
      return "Radius: "+str(self._radius)
class Sphere(Shape3D):
    def __init__(self)



ph = Sphere('Sphere', 5)
print('----------------------------------')
sph.calc_surface_area()
print(sph)
print('==================================')
cyl = Cylinder('Cylinder', 5, 10)
print('----------------------------------')
cyl.calc_surface_area()
print(cyl)

# %%
#task-1
class RealNumber:

    def __init__(self, r=0):
        self.__realValue = r
    def getRealValue(self):
        return self.__realValue
    def setRealValue(self, r):
        self.__realValue = r
    def __str__(self):
        return 'RealPart: '+str(self.getRealValue())
class ComplexNumber(RealNumber):
    def __init__(self):


cn1 = ComplexNumber()
print(cn1)
print('---------')
cn2 = ComplexNumber(5,7)
print(cn2)
